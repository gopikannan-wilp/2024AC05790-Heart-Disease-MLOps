# %% [markdown]
# # AIMLCZG523 - MLOps Assignment 01
#
# ## Heart Disease Risk Prediction
#
# This notebook supports the end-to-end MLOps assignment deliverables.

# %% [markdown]
# ## Assignment Mapping
#
# The project covers data acquisition, EDA, model development, MLflow tracking, packaging, testing, containerization, CI/CD, deployment, monitoring and reporting.

# %%
# !python scripts/download_data.py

# %%
# !python src/eda.py

# %%
# !python src/train.py

# %% [markdown]
# ## API Testing
#
# Run the API using `uvicorn src.api:app --reload`, then open `http://127.0.0.1:8000/docs`.

# %% [markdown]
# ## Docker and Kubernetes
#
# Build Docker image, run the container, then apply Kubernetes deployment and service manifests from the `k8s/` folder.
